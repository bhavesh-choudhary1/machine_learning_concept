# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavesh-choudhary1/machine_learning_concept/blob/main/Binarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score

from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('train.csv',usecols=['Age','Fare','SibSp','Parch','Survived'])

# %%
df.head(5)
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
df['Family'] = df['SibSp'] + df['Parch']

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  Family
# 0         0  22.0      1      0   7.2500       1
# 1         1  38.0      1      0  71.2833       1
# 2         1  26.0      0      0   7.9250       0
# 3         1  35.0      1      0  53.1000       1
# 4         0  35.0      0      0   8.0500       0

# %%
df.drop(columns=['SibSp','Parch'],inplace=True)

# %%
df.head()
# Out:
#    Survived   Age     Fare  Family
# 0         0  22.0   7.2500       1
# 1         1  38.0  71.2833       1
# 2         1  26.0   7.9250       0
# 3         1  35.0  53.1000       1
# 4         0  35.0   8.0500       0

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#       Age     Fare  Family
# 328  31.0  20.5250       2
# 73   26.0  14.4542       1
# 253  30.0  16.1000       1
# 719  33.0   7.7750       0
# 666  25.0  13.0000       0

# %%
x_test
# Out:
#       Age     Fare  Family
# 149  42.0  13.0000       0
# 407   3.0  18.7500       2
# 53   29.0  26.0000       1
# 369  24.0  69.3000       0
# 818  43.0   6.4500       0
# ..    ...      ...     ...
# 819  10.0  27.9000       5
# 164   1.0  39.6875       5
# 363  35.0   7.0500       0
# 56   21.0  10.5000       0
# 136  19.0  26.2833       2
#
# [143 rows x 3 columns]

# %%
#without binarization

clf = DecisionTreeClassifier()

clf.fit(x_train,y_train)

y_pred = clf.predict(x_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.6153846153846154

# %%
np.mean(cross_val_score(DecisionTreeClassifier(),x,y,cv=10,scoring='accuracy'))
# Out:
# 0.6457550860719874

# %%
#applying Binarization

from sklearn.preprocessing import Binarizer

# %%
trf = ColumnTransformer([
    ('bin',Binarizer(copy=False),['Family'])
],remainder='passthrough')

# %%
x_train_trf = trf.fit_transform(x_train)
x_test_trf = trf.transform(x_test)

# %%
pd.DataFrame(x_train_trf,columns=['Family','Age','Fare'])
# Out:
#      Family   Age      Fare
# 0       1.0  31.0   20.5250
# 1       1.0  26.0   14.4542
# 2       1.0  30.0   16.1000
# 3       0.0  33.0    7.7750
# 4       0.0  25.0   13.0000
# ..      ...   ...       ...
# 566     1.0  46.0   61.1750
# 567     0.0  25.0   13.0000
# 568     0.0  41.0  134.5000
# 569     1.0  33.0   20.5250
# 570     0.0  33.0    7.8958
#
# [571 rows x 3 columns]

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train_trf,y_train)
y_pred2 = clf.predict(x_test_trf)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.6013986013986014

# %%
x_trf = trf.fit_transform(x)
np.mean(cross_val_score(DecisionTreeClassifier(),x_trf,y,cv=10,scoring='accuracy'))
# Out:
# 0.6248043818466356
