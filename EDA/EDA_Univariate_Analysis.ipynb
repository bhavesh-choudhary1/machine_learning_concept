# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavesh-choudhary1/machine_learning_concept/blob/main/EDA_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Categorial Data Analysis **

# %%
#categorical Data :
#Survived
#Pclass
#Name
#Sex
#Sibsp
#Parch
#Ticket
#Cabin
#Embarked'''

# %%
#count plot
import seaborn as sns
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
#as the name have many categoriacal value it is not properly shown in graph so it is not possible to understand

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# **2. Pie Chart **

# %%
#it is used for the same purpose as the countplot but it gives the output in percentage

# %%
from enum import auto
df['Survived'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **Numerical Data Analysis **

# %% [markdown]
# a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(x='Fare',data= df, bins=15)
# Out:
# (array([687.,  90.,  61.,  22.,  11.,   0.,   9.,   8.,   0.,   0.,   0.,
#           0.,   0.,   0.,   3.]),
#  array([  0.     ,  34.15528,  68.31056, 102.46584, 136.62112, 170.7764 ,
#         204.93168, 239.08696, 273.24224, 307.39752, 341.5528 , 375.70808,
#         409.86336, 444.01864, 478.17392, 512.3292 ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# <ipython-input-19-0fafe04ea3f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Fare'])
# Out:
# <ipython-input-20-70b4b4beb1b5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
